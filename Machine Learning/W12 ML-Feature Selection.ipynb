# %%
from scipy.stats import pearsonr
pearsonr([1,2,3,4,5], [1,2,4,7,8])
# Out:
# (0.985104109993904, 0.0021775131135874748)

# %%
pearsonr([1,2,3,4,5], [4,3,3,2,2])
# Out:
# (-0.944911182523068, 0.01539243807330231)

# %%
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=100, n_features=10, n_informative=3, random_state=0)
# samples 만들어낼 샘플 수
# features 만들어낼 피처들 수
# informative 의미있는 제공정보량이 많은 피처 수
# classes 만들어낼 클래스 수 default=2

# %%
X[:5], X.shape
# Out:
# (array([[ 0.20654985, -1.99440882,  0.12454664, -3.24905569,  0.65449813,
#          -2.6280211 , -0.90499455,  1.11522162,  1.54624556,  1.81536279],
#         [ 0.35924959,  0.68839784, -1.72538572,  2.30587309,  0.20501309,
#           2.45509176,  0.88193495,  1.17574587,  1.4306019 ,  1.27075915],
#         [-0.06794353, -2.44499934, -0.34361726, -0.40268287, -1.51501515,
#           0.44301848,  1.17658723,  0.79358489, -2.25126119,  2.53139107],
#         [-0.51100852,  0.51505188, -1.00218322, -0.28045437,  0.99274477,
#          -0.70458471, -1.97161176, -1.3464816 , -0.60891701, -1.83463171],
#         [ 1.09854667,  3.09499716, -0.74226929, -2.09995255, -2.30105665,
#          -3.24335   , -1.29482133, -0.64582754,  1.21169846, -3.4882127 ]]),
#  (100, 10))

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X,y)

selector = RFE(clf, n_features_to_select=3)
selector = selector.fit(X,y)

# %%
selector.support_
# Out:
# array([False, False,  True, False, False, False,  True,  True, False,
#        False])

# %%
selector.ranking_
# Out:
# array([5, 4, 1, 2, 6, 7, 1, 1, 8, 3])
